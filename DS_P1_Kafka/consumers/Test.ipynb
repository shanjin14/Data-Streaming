# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from confluent_kafka import Consumer, KafkaError
from confluent_kafka.avro import AvroConsumer
from confluent_kafka.avro.serializer import SerializerError
c = AvroConsumer({
    'bootstrap.servers': 'PLAINTEXT://localhost:9092',
    'group.id': 'mygroup',
    'default.topic.config': {
        'auto.offset.reset': 'earliest'
    },
    'schema.registry.url': 'http://localhost:8081'
})
c.subscribe(['^com.cta.stations.arrival.*'])
i =0
while True:
    try:
        i+=1
        print('Polling for message',i)
        msg = c.poll(1)
        
    except SerializerError as e:
        print("Message deserialization failed for {}: {}".format(msg, e))
        break
    if msg is None:
        print("Message is None")
        continue
    if msg.error():
        print("AvroConsumer error: {}".format(msg.error()))
        continue
    print(msg.value(),msg.topic())
c.close()
# Out:
# Polling for message 1
# Message is None
# Polling for message 2
# Message is None
# Polling for message 3
# Message is None
# Polling for message 4
# Message is None
# Polling for message 5
# Message is None
# Polling for message 6
# Message is None
# Polling for message 7
# Message is None
# Polling for message 8
# Message is None
# Polling for message 9
# Message is None
# Polling for message 10
# Message is None
# Polling for message 11
# Message is None
# Polling for message 12
# Message is None
# Polling for message 13
# Message is None
# Polling for message 14
# Message is None
# Polling for message 15
# Message is None
# Polling for message 16
# Message is None
# Polling for message 17
# Message is None
# Polling for message 18
# Message is None
# Polling for message 19
# Message is None
# Polling for message 20
# Message is None
# Polling for message 21
# Message is None
# Polling for message 22
# Message is None
# Polling for message 23
# Message is None
# Polling for message 24
# Message is None
# Polling for message 25
# Message is None
# Polling for message 26
# Message is None
# Polling for message 27
# Message is None
# Polling for message 28
# Message is None
# Polling for message 29
# Message is None
# Polling for message 30
# Message is None
# Polling for message 31
# Message is None
# Polling for message 32
# Message is None
# Polling for message 33
# Message is None
# Polling for message 34
# Message is None
# Polling for message 35
# Message is None
# Polling for message 36
# Message is None
# Polling for message 37
# Message is None
# Polling for message 38
# Message is None
# Polling for message 39
# Message is None
# Polling for message 40
# Message is None
# Polling for message 41
# Message is None
# Polling for message 42
# Message is None
# Polling for message 43
# Message is None
# Polling for message 44
# Message is None
# Polling for message 45
# Message is None
# Polling for message 46
# Message is None
# Polling for message 47
# Message is None
# Polling for message 48
# Message is None
# Polling for message 49
# Message is None
# Polling for message 50
# Message is None
# Polling for message 51
# Message is None
# Polling for message 52
# Message is None
# Polling for message 53
# Message is None
# Polling for message 54
# Message is None
# Polling for message 55
# Message is None
# Polling for message 56
# Message is None
# Polling for message 57
# Message is None
# Polling for message 58
# Message is None
# Polling for message 59
# Message is None
# Polling for message 60
# Message is None
# Polling for message 61
# Message is None
# Polling for message 62
# Message is None
# Polling for message 63
# Message is None
# Polling for message 64
# Message is None
# Polling for message 65
# Message is None
# Polling for message 66
# Message is None
# Polling for message 67
# Message is None
# Polling for message 68
# Message is None
# Polling for message 69
# Message is None
# Polling for message 70
# Message is None
# Polling for message 71
# Message is None
# Polling for message 72
# Message is None
# Polling for message 73
# Message is None
# Polling for message 74
# Message is None
# Polling for message 75
# Message is None
# Polling for message 76
# Message is None
# Polling for message 77
# Message is None
# Polling for message 78
# Message is None
# Polling for message 79
# Message is None
# Polling for message 80
# Message is None
# Polling for message 81
# Message is None
# Polling for message 82
# Message is None
# Polling for message 83
# Message is None
# Polling for message 84
# Message is None
# Polling for message 85
# Message is None
# Polling for message 86
# Message is None
# Polling for message 87
# Message is None
# Polling for message 88
# Message is None
# Polling for message 89
# Message is None
# Polling for message 90
# Message is None
# Polling for message 91
# Message is None
# Polling for message 92
# Message is None
# Polling for message 93
# Message is None
# Polling for message 94
# Message is None
# Polling for message 95
# Message is None
# Polling for message 96
# Message is None
# Polling for message 97
# Message is None
# Polling for message 98
# Message is None
# Polling for message 99
# Message is None
# Polling for message 100
# Message is None
# Polling for message 101
# Message is None
# Polling for message 102
# Message is None
# Polling for message 103
# Message is None
# Polling for message 104
# Message is None
# Polling for message 105
# Message is None
# Polling for message 106
# Message is None
# Polling for message 107
# Message is None
# Polling for message 108
# Message is None
# Polling for message 109
# Message is None
# Polling for message 110
# Message is None
# Polling for message 111
# Message is None
# Polling for message 112
# Message is None
# Polling for message 113
# Message is None
# Polling for message 114
# Message is None
# Polling for message 115
# Message is None
# Polling for message 116
# Message is None
# Polling for message 117
# Message is None
# Polling for message 118
# Message is None
# Polling for message 119
# Message is None
# Polling for message 120
# Message is None
# Polling for message 121
# Message is None
# Polling for message 122
# Message is None
# Polling for message 123
# Message is None
# Polling for message 124
# Message is None
# Polling for message 125
# Message is None
# Polling for message 126
# Message is None
# Polling for message 127
# Message is None
# Polling for message 128
# Message is None
# Polling for message 129
# Message is None
# Polling for message 130
# Message is None
# Polling for message 131
# Message is None
# Polling for message 132
# Message is None
# Polling for message 133
# Message is None
# Polling for message 134
# Message is None
# Polling for message 135
# Message is None
# Polling for message 136
# Message is None
# Polling for message 137
# Message is None
# Polling for message 138
# Message is None
# Polling for message 139
# Message is None
# Polling for message 140
# Message is None
# Polling for message 141
# Message is None
# Polling for message 142
# Message is None
# Polling for message 143
# Message is None
# Polling for message 144
# Message is None
# Polling for message 145
# Message is None
# Polling for message 146
# Message is None
# Polling for message 147
# Message is None
# Polling for message 148
# Message is None
# Polling for message 149
# Message is None
# Polling for message 150
# Message is None
# Polling for message 151
# Message is None
# Polling for message 152
# Message is None
# Polling for message 153
# Message is None
# Polling for message 154
# Message is None
# Polling for message 155
# Message is None
# Polling for message 156
# Message is None
# Polling for message 157
# Message is None
# Polling for message 158
# Message is None
# Polling for message 159
# Message is None
# Polling for message 160
# Message is None
# Polling for message 161
# Message is None
# Polling for message 162
# Message is None
# Polling for message 163
# Message is None
# Polling for message 164
# Message is None
# Polling for message 165
# Message is None
# Polling for message 166
# Message is None
# Polling for message 167
# Message is None
# Polling for message 168
# Message is None
# Polling for message 169
# Message is None
# Polling for message 170
# Message is None
# Polling for message 171
# Message is None
# Polling for message 172
# Message is None
# Polling for message 173
# Message is None
# Polling for message 174
# Message is None
# Polling for message 175
# Message is None
# Polling for message 176
# Message is None
# Polling for message 177
# Message is None
# Polling for message 178
# Message is None
# Polling for message 179
# Message is None
# Polling for message 180
# Message is None
# Polling for message 181
# Message is None
# Polling for message 182
# Message is None
# Polling for message 183
# Message is None
# Polling for message 184
# Message is None
# Polling for message 185
# Message is None
# Polling for message 186
# Message is None
# Polling for message 187
# Message is None
# Polling for message 188
# Message is None
# Polling for message 189
# Message is None
# Polling for message 190
# Message is None
# Polling for message 191
# Message is None
# Polling for message 192
# Message is None
# Polling for message 193
# Message is None
# Polling for message 194
# Message is None
# Polling for message 195
# Message is None
# Polling for message 196
# Message is None
# Polling for message 197
# Message is None
# Polling for message 198
# Message is None
# Polling for message 199
# Message is None
# Polling for message 200
# Message is None
# Polling for message 201
# Message is None
# Polling for message 202
# Message is None
# Polling for message 203
# Message is None
# Polling for message 204
# Message is None
# Polling for message 205
# Message is None
# Polling for message 206
# Message is None
# Polling for message 207
# Message is None
# Polling for message 208
# Message is None
# Polling for message 209
# Message is None
# Polling for message 210
# Message is None
# Polling for message 211
# Message is None
# Polling for message 212
# Message is None
# Polling for message 213
# Message is None
# Polling for message 214
# Message is None
# Polling for message 215
# Message is None
# Polling for message 216
# Message is None
# Polling for message 217
# Message is None
# Polling for message 218
# Message is None
# Polling for message 219
# Message is None
# Polling for message 220
# Message is None
# Polling for message 221
# Message is None
# Polling for message 222
# Message is None
# Polling for message 223
# Message is None
# Polling for message 224
# Message is None
# Polling for message 225
# Message is None
# Polling for message 226
# Message is None
# Polling for message 227
# Message is None
# Polling for message 228
# Message is None
# Polling for message 229
# Message is None
# Polling for message 230
# Message is None
# Polling for message 231
# Message is None
# Polling for message 232
# Message is None
# Polling for message 233
# Message is None
# Polling for message 234
# Message is None
# Polling for message 235
# Message is None
# Polling for message 236
# Message is None
# Polling for message 237
# Message is None
# Polling for message 238
# Message is None
# Polling for message 239
# Message is None
# Polling for message 240
# Message is None
# Polling for message 241
# Message is None
# Polling for message 242
# Message is None
# Polling for message 243
# Message is None
# Polling for message 244
# Message is None
# Polling for message 245
# Message is None
# Polling for message 246
# Message is None
# Polling for message 247
# Message is None
# Polling for message 248
# Message is None
# Polling for message 249
# Message is None
# Polling for message 250
# Message is None
# Polling for message 251
# Message is None
# Polling for message 252
# Message is None
# Polling for message 253
# Message is None
# Polling for message 254
# Message is None
# Polling for message 255
# Message is None
# Polling for message 256
# Message is None
# Polling for message 257
# Message is None
# Polling for message 258
# Message is None
# Polling for message 259
# Message is None
# Polling for message 260
# Message is None
# Polling for message 261
# Message is None
# Polling for message 262
# Message is None
# Polling for message 263
# Message is None
# Polling for message 264
# Message is None
# Polling for message 265
# Message is None
# Polling for message 266
# Message is None
# Polling for message 267
# Message is None
# Polling for message 268
# Message is None
# Polling for message 269
# Message is None
# Polling for message 270
# Message is None
# Polling for message 271
# Message is None
# Polling for message 272
# Message is None
# Polling for message 273
# Message is None
# Polling for message 274
# Message is None
# Polling for message 275
# Message is None
# Polling for message 276
# Message is None
# Polling for message 277
# Message is None
# Polling for message 278
# Message is None
# Polling for message 279
# Message is None
# Polling for message 280
# Message is None
# Polling for message 281
# Message is None
# Polling for message 282
# Message is None
# Polling for message 283
# Message is None
# Polling for message 284
# Message is None
# Polling for message 285
# Message is None
# Polling for message 286
# Message is None
# Polling for message 287
# Message is None
# Polling for message 288
# Message is None
# Polling for message 289
# Message is None
# Polling for message 290
# Message is None
# Polling for message 291
# Message is None
# Polling for message 292
# Message is None
# Polling for message 293
# Message is None
# Polling for message 294
# Message is None
# Polling for message 295
# Message is None
# Polling for message 296
# Message is None
# Polling for message 297
# Message is None
# Polling for message 298
# Message is None
# Polling for message 299
# Message is None
# Polling for message 300
# {'station_id': 41200, 'train_id': 'RL006', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40340, 'prev_direction': 'b'} com.cta.stations.arrival.argyle
# Polling for message 301
# {'station_id': 41200, 'train_id': 'RL003', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40770, 'prev_direction': 'a'} com.cta.stations.arrival.argyle
# Polling for message 302
# {'station_id': 41200, 'train_id': 'RL005', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40340, 'prev_direction': 'b'} com.cta.stations.arrival.argyle
# Polling for message 303
# {'station_id': 41200, 'train_id': 'RL002', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40770, 'prev_direction': 'a'} com.cta.stations.arrival.argyle
# Polling for message 304
# {'station_id': 41200, 'train_id': 'RL004', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40340, 'prev_direction': 'b'} com.cta.stations.arrival.argyle
# Polling for message 305
# {'station_id': 41200, 'train_id': 'RL001', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40770, 'prev_direction': 'a'} com.cta.stations.arrival.argyle
# Polling for message 306
# {'station_id': 41200, 'train_id': 'RL003', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40340, 'prev_direction': 'b'} com.cta.stations.arrival.argyle
# Polling for message 307
# {'station_id': 41200, 'train_id': 'RL000', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40770, 'prev_direction': 'a'} com.cta.stations.arrival.argyle
# Polling for message 308
# {'station_id': 41200, 'train_id': 'RL002', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40340, 'prev_direction': 'b'} com.cta.stations.arrival.argyle
# Polling for message 309
# {'station_id': 41200, 'train_id': 'RL001', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40340, 'prev_direction': 'b'} com.cta.stations.arrival.argyle
# Polling for message 310
# {'station_id': 41200, 'train_id': 'RL009', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40770, 'prev_direction': 'a'} com.cta.stations.arrival.argyle
# Polling for message 311
# {'station_id': 41200, 'train_id': 'RL000', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40340, 'prev_direction': 'b'} com.cta.stations.arrival.argyle
# Polling for message 312
# {'station_id': 41200, 'train_id': 'RL008', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40770, 'prev_direction': 'a'} com.cta.stations.arrival.argyle
# Polling for message 313
# {'station_id': 41200, 'train_id': 'RL007', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40770, 'prev_direction': 'a'} com.cta.stations.arrival.argyle
# Polling for message 314
# {'station_id': 41200, 'train_id': 'RL009', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40340, 'prev_direction': 'b'} com.cta.stations.arrival.argyle
# Polling for message 315
# {'station_id': 41200, 'train_id': 'RL006', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40770, 'prev_direction': 'a'} com.cta.stations.arrival.argyle
# Polling for message 316
# {'station_id': 41200, 'train_id': 'RL008', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40340, 'prev_direction': 'b'} com.cta.stations.arrival.argyle
# Polling for message 317
# {'station_id': 40130, 'train_id': 'GL001', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41080, 'prev_direction': 'b'} com.cta.stations.arrival.51st
# Polling for message 318
# {'station_id': 40130, 'train_id': 'GL002', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40510, 'prev_direction': 'a'} com.cta.stations.arrival.51st
# Polling for message 319
# {'station_id': 40130, 'train_id': 'GL000', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41080, 'prev_direction': 'b'} com.cta.stations.arrival.51st
# Polling for message 320
# {'station_id': 40130, 'train_id': 'GL001', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40510, 'prev_direction': 'a'} com.cta.stations.arrival.51st
# Polling for message 321
# {'station_id': 40130, 'train_id': 'GL000', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40510, 'prev_direction': 'a'} com.cta.stations.arrival.51st
# Polling for message 322
# {'station_id': 40130, 'train_id': 'GL009', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41080, 'prev_direction': 'b'} com.cta.stations.arrival.51st
# Polling for message 323
# {'station_id': 40130, 'train_id': 'GL008', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41080, 'prev_direction': 'b'} com.cta.stations.arrival.51st
# Polling for message 324
# {'station_id': 40130, 'train_id': 'GL009', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40510, 'prev_direction': 'a'} com.cta.stations.arrival.51st
# Polling for message 325
# {'station_id': 40130, 'train_id': 'GL007', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41080, 'prev_direction': 'b'} com.cta.stations.arrival.51st
# Polling for message 326
# {'station_id': 40130, 'train_id': 'GL008', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40510, 'prev_direction': 'a'} com.cta.stations.arrival.51st
# Polling for message 327
# {'station_id': 40130, 'train_id': 'GL006', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41080, 'prev_direction': 'b'} com.cta.stations.arrival.51st
# Polling for message 328
# {'station_id': 40130, 'train_id': 'GL007', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40510, 'prev_direction': 'a'} com.cta.stations.arrival.51st
# Polling for message 329
# {'station_id': 40130, 'train_id': 'GL005', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41080, 'prev_direction': 'b'} com.cta.stations.arrival.51st
# Polling for message 330
# {'station_id': 40130, 'train_id': 'GL006', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40510, 'prev_direction': 'a'} com.cta.stations.arrival.51st
# Polling for message 331
# {'station_id': 40130, 'train_id': 'GL004', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41080, 'prev_direction': 'b'} com.cta.stations.arrival.51st
# Polling for message 332
# {'station_id': 40130, 'train_id': 'GL005', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40510, 'prev_direction': 'a'} com.cta.stations.arrival.51st
# Polling for message 333
# {'station_id': 40130, 'train_id': 'GL003', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41080, 'prev_direction': 'b'} com.cta.stations.arrival.51st
# Polling for message 334
# {'station_id': 40130, 'train_id': 'GL004', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40510, 'prev_direction': 'a'} com.cta.stations.arrival.51st
# Polling for message 335
# {'station_id': 40130, 'train_id': 'GL002', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41080, 'prev_direction': 'b'} com.cta.stations.arrival.51st
# Polling for message 336
# {'station_id': 40130, 'train_id': 'GL003', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40510, 'prev_direction': 'a'} com.cta.stations.arrival.51st
# Polling for message 337
# {'station_id': 40130, 'train_id': 'GL001', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41080, 'prev_direction': 'b'} com.cta.stations.arrival.51st
# Polling for message 338
# {'station_id': 40130, 'train_id': 'GL002', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40510, 'prev_direction': 'a'} com.cta.stations.arrival.51st
# Polling for message 339
# {'station_id': 40750, 'train_id': 'BL002', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40230, 'prev_direction': 'b'} com.cta.stations.arrival.harlem
# Polling for message 340
# {'station_id': 40750, 'train_id': 'BL001', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 41280, 'prev_direction': 'a'} com.cta.stations.arrival.harlem
# Polling for message 341
# {'station_id': 40750, 'train_id': 'BL001', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40230, 'prev_direction': 'b'} com.cta.stations.arrival.harlem
# Polling for message 342
# {'station_id': 40750, 'train_id': 'BL000', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 41280, 'prev_direction': 'a'} com.cta.stations.arrival.harlem
# Polling for message 343
# {'station_id': 40750, 'train_id': 'BL000', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40230, 'prev_direction': 'b'} com.cta.stations.arrival.harlem
# Polling for message 344
# {'station_id': 40750, 'train_id': 'BL009', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 41280, 'prev_direction': 'a'} com.cta.stations.arrival.harlem
# Polling for message 345
# {'station_id': 40750, 'train_id': 'BL009', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40230, 'prev_direction': 'b'} com.cta.stations.arrival.harlem
# Polling for message 346
# {'station_id': 40750, 'train_id': 'BL008', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 41280, 'prev_direction': 'a'} com.cta.stations.arrival.harlem
# Polling for message 347
# {'station_id': 40750, 'train_id': 'BL008', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40230, 'prev_direction': 'b'} com.cta.stations.arrival.harlem
# Polling for message 348
# {'station_id': 40750, 'train_id': 'BL007', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 41280, 'prev_direction': 'a'} com.cta.stations.arrival.harlem
# Polling for message 349
# {'station_id': 40750, 'train_id': 'BL007', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40230, 'prev_direction': 'b'} com.cta.stations.arrival.harlem
# Polling for message 350
# {'station_id': 40750, 'train_id': 'BL006', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 41280, 'prev_direction': 'a'} com.cta.stations.arrival.harlem
# Polling for message 351
# {'station_id': 40750, 'train_id': 'BL006', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40230, 'prev_direction': 'b'} com.cta.stations.arrival.harlem
# Polling for message 352
# {'station_id': 40750, 'train_id': 'BL005', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 41280, 'prev_direction': 'a'} com.cta.stations.arrival.harlem
# Polling for message 353
# {'station_id': 40750, 'train_id': 'BL005', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40230, 'prev_direction': 'b'} com.cta.stations.arrival.harlem
# Polling for message 354
# {'station_id': 40750, 'train_id': 'BL004', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 41280, 'prev_direction': 'a'} com.cta.stations.arrival.harlem
# Polling for message 355
# {'station_id': 40750, 'train_id': 'BL004', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40230, 'prev_direction': 'b'} com.cta.stations.arrival.harlem
# Polling for message 356
# {'station_id': 40750, 'train_id': 'BL003', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 41280, 'prev_direction': 'a'} com.cta.stations.arrival.harlem
# Polling for message 357
# {'station_id': 41190, 'train_id': 'RL005', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40900, 'prev_direction': 'b'} com.cta.stations.arrival.jarvis
# Polling for message 358
# {'station_id': 41190, 'train_id': 'RL004', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40100, 'prev_direction': 'a'} com.cta.stations.arrival.jarvis
# Polling for message 359
# {'station_id': 41190, 'train_id': 'RL004', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40900, 'prev_direction': 'b'} com.cta.stations.arrival.jarvis
# Polling for message 360
# {'station_id': 41190, 'train_id': 'RL003', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40100, 'prev_direction': 'a'} com.cta.stations.arrival.jarvis
# Polling for message 361
# {'station_id': 41190, 'train_id': 'RL003', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40900, 'prev_direction': 'b'} com.cta.stations.arrival.jarvis
# Polling for message 362
# {'station_id': 41190, 'train_id': 'RL002', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40100, 'prev_direction': 'a'} com.cta.stations.arrival.jarvis
# Polling for message 363
# {'station_id': 41190, 'train_id': 'RL002', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40900, 'prev_direction': 'b'} com.cta.stations.arrival.jarvis
# Polling for message 364
# {'station_id': 41190, 'train_id': 'RL001', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40100, 'prev_direction': 'a'} com.cta.stations.arrival.jarvis
# Polling for message 365
# {'station_id': 41190, 'train_id': 'RL001', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40900, 'prev_direction': 'b'} com.cta.stations.arrival.jarvis
# Polling for message 366
# {'station_id': 41190, 'train_id': 'RL000', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40100, 'prev_direction': 'a'} com.cta.stations.arrival.jarvis
# Polling for message 367
# {'station_id': 41190, 'train_id': 'RL000', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40900, 'prev_direction': 'b'} com.cta.stations.arrival.jarvis
# Polling for message 368
# {'station_id': 41190, 'train_id': 'RL009', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40100, 'prev_direction': 'a'} com.cta.stations.arrival.jarvis
# Polling for message 369
# {'station_id': 41190, 'train_id': 'RL009', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40900, 'prev_direction': 'b'} com.cta.stations.arrival.jarvis
# Polling for message 370
# {'station_id': 41190, 'train_id': 'RL008', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40100, 'prev_direction': 'a'} com.cta.stations.arrival.jarvis
# Polling for message 371
# {'station_id': 41190, 'train_id': 'RL008', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40900, 'prev_direction': 'b'} com.cta.stations.arrival.jarvis
# Polling for message 372
# {'station_id': 41190, 'train_id': 'RL007', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40100, 'prev_direction': 'a'} com.cta.stations.arrival.jarvis
# Polling for message 373
# {'station_id': 41190, 'train_id': 'RL007', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40900, 'prev_direction': 'b'} com.cta.stations.arrival.jarvis
# Polling for message 374
# {'station_id': 40610, 'train_id': 'GL007', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41350, 'prev_direction': 'b'} com.cta.stations.arrival.ridgeland
# Polling for message 375
# {'station_id': 40610, 'train_id': 'GL006', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41260, 'prev_direction': 'a'} com.cta.stations.arrival.ridgeland
# Polling for message 376
# {'station_id': 40610, 'train_id': 'GL006', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41350, 'prev_direction': 'b'} com.cta.stations.arrival.ridgeland
# Polling for message 377
# {'station_id': 40610, 'train_id': 'GL005', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41260, 'prev_direction': 'a'} com.cta.stations.arrival.ridgeland
# Polling for message 378
# {'station_id': 40610, 'train_id': 'GL005', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41350, 'prev_direction': 'b'} com.cta.stations.arrival.ridgeland
# Polling for message 379
# {'station_id': 40610, 'train_id': 'GL004', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41260, 'prev_direction': 'a'} com.cta.stations.arrival.ridgeland
# Polling for message 380
# {'station_id': 40610, 'train_id': 'GL004', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41350, 'prev_direction': 'b'} com.cta.stations.arrival.ridgeland
# Polling for message 381
# {'station_id': 40610, 'train_id': 'GL003', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41260, 'prev_direction': 'a'} com.cta.stations.arrival.ridgeland
# Polling for message 382
# {'station_id': 40610, 'train_id': 'GL003', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41350, 'prev_direction': 'b'} com.cta.stations.arrival.ridgeland
# Polling for message 383
# {'station_id': 40610, 'train_id': 'GL002', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41260, 'prev_direction': 'a'} com.cta.stations.arrival.ridgeland
# Polling for message 384
# {'station_id': 40610, 'train_id': 'GL002', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41350, 'prev_direction': 'b'} com.cta.stations.arrival.ridgeland
# Polling for message 385
# {'station_id': 40610, 'train_id': 'GL001', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41260, 'prev_direction': 'a'} com.cta.stations.arrival.ridgeland
# Polling for message 386
# {'station_id': 40610, 'train_id': 'GL001', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41350, 'prev_direction': 'b'} com.cta.stations.arrival.ridgeland
# Polling for message 387
# {'station_id': 40610, 'train_id': 'GL000', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41260, 'prev_direction': 'a'} com.cta.stations.arrival.ridgeland
# Polling for message 388
# {'station_id': 40610, 'train_id': 'GL000', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41350, 'prev_direction': 'b'} com.cta.stations.arrival.ridgeland
# Polling for message 389
# {'station_id': 40610, 'train_id': 'GL009', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41260, 'prev_direction': 'a'} com.cta.stations.arrival.ridgeland
# Polling for message 390
# {'station_id': 40610, 'train_id': 'GL009', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41350, 'prev_direction': 'b'} com.cta.stations.arrival.ridgeland
# Polling for message 391
# {'station_id': 40610, 'train_id': 'GL008', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41260, 'prev_direction': 'a'} com.cta.stations.arrival.ridgeland
# Polling for message 392
# {'station_id': 40610, 'train_id': 'GL008', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41350, 'prev_direction': 'b'} com.cta.stations.arrival.ridgeland
# Polling for message 393
# {'station_id': 40610, 'train_id': 'GL007', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41260, 'prev_direction': 'a'} com.cta.stations.arrival.ridgeland
# Polling for message 394
# {'station_id': 41400, 'train_id': 'RL001', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41000, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 395
# {'station_id': 41400, 'train_id': 'GL003', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41690, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 396
# {'station_id': 41400, 'train_id': 'RL008', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41490, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 397
# {'station_id': 41400, 'train_id': 'RL000', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41000, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 398
# {'station_id': 41400, 'train_id': 'GL002', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41690, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 399
# {'station_id': 41400, 'train_id': 'GL009', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40680, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 400
# {'station_id': 41400, 'train_id': 'RL007', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41490, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 401
# {'station_id': 41400, 'train_id': 'GL001', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41690, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 402
# {'station_id': 41400, 'train_id': 'GL008', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40680, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 403
# {'station_id': 41400, 'train_id': 'RL006', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41490, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 404
# {'station_id': 41400, 'train_id': 'GL000', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41690, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 405
# {'station_id': 41400, 'train_id': 'RL009', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41000, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 406
# {'station_id': 41400, 'train_id': 'GL007', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40680, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 407
# {'station_id': 41400, 'train_id': 'RL005', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41490, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 408
# {'station_id': 41400, 'train_id': 'GL006', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40680, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 409
# {'station_id': 41400, 'train_id': 'RL008', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41000, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 410
# {'station_id': 41400, 'train_id': 'GL009', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41690, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 411
# {'station_id': 41400, 'train_id': 'RL004', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41490, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 412
# {'station_id': 41400, 'train_id': 'GL005', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40680, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 413
# {'station_id': 41400, 'train_id': 'RL007', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41000, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 414
# {'station_id': 41400, 'train_id': 'GL008', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41690, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 415
# {'station_id': 41400, 'train_id': 'GL004', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40680, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 416
# {'station_id': 41400, 'train_id': 'RL003', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41490, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 417
# {'station_id': 41400, 'train_id': 'RL006', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41000, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 418
# {'station_id': 41400, 'train_id': 'GL007', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41690, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 419
# {'station_id': 41400, 'train_id': 'GL003', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40680, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 420
# {'station_id': 41400, 'train_id': 'RL002', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41490, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 421
# {'station_id': 41400, 'train_id': 'GL006', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41690, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 422
# {'station_id': 41400, 'train_id': 'RL005', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41000, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 423
# {'station_id': 41400, 'train_id': 'GL002', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40680, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 424
# {'station_id': 41400, 'train_id': 'RL001', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41490, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 425
# {'station_id': 41400, 'train_id': 'GL005', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41690, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 426
# {'station_id': 41400, 'train_id': 'RL004', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41000, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 427
# {'station_id': 41400, 'train_id': 'GL001', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40680, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 428
# {'station_id': 41400, 'train_id': 'GL004', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41690, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 429
# {'station_id': 41400, 'train_id': 'RL000', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41490, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 430
# {'station_id': 41400, 'train_id': 'GL000', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40680, 'prev_direction': 'b'} com.cta.stations.arrival.roosevelt
# Polling for message 431
# {'station_id': 41400, 'train_id': 'RL003', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41000, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 432
# {'station_id': 40450, 'train_id': 'RL009', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41430, 'prev_direction': 'b'} com.cta.stations.arrival.95th_and_dan_ryan
# Polling for message 433
# {'station_id': 40450, 'train_id': 'RL009', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40450, 'prev_direction': 'a'} com.cta.stations.arrival.95th_and_dan_ryan
# Polling for message 434
# {'station_id': 40450, 'train_id': 'RL008', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41430, 'prev_direction': 'b'} com.cta.stations.arrival.95th_and_dan_ryan
# Polling for message 435
# {'station_id': 40450, 'train_id': 'RL008', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40450, 'prev_direction': 'a'} com.cta.stations.arrival.95th_and_dan_ryan
# Polling for message 436
# {'station_id': 40450, 'train_id': 'RL007', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41430, 'prev_direction': 'b'} com.cta.stations.arrival.95th_and_dan_ryan
# Polling for message 437
# {'station_id': 40450, 'train_id': 'RL007', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40450, 'prev_direction': 'a'} com.cta.stations.arrival.95th_and_dan_ryan
# Polling for message 438
# {'station_id': 40450, 'train_id': 'RL006', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41430, 'prev_direction': 'b'} com.cta.stations.arrival.95th_and_dan_ryan
# Polling for message 439
# {'station_id': 40450, 'train_id': 'RL006', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40450, 'prev_direction': 'a'} com.cta.stations.arrival.95th_and_dan_ryan
# Polling for message 440
# {'station_id': 40450, 'train_id': 'RL005', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41430, 'prev_direction': 'b'} com.cta.stations.arrival.95th_and_dan_ryan
# Polling for message 441
# {'station_id': 40450, 'train_id': 'RL005', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40450, 'prev_direction': 'a'} com.cta.stations.arrival.95th_and_dan_ryan
# Polling for message 442
# {'station_id': 40450, 'train_id': 'RL004', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41430, 'prev_direction': 'b'} com.cta.stations.arrival.95th_and_dan_ryan
# Polling for message 443
# {'station_id': 40450, 'train_id': 'RL004', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40450, 'prev_direction': 'a'} com.cta.stations.arrival.95th_and_dan_ryan
# Polling for message 444
# {'station_id': 40450, 'train_id': 'RL003', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41430, 'prev_direction': 'b'} com.cta.stations.arrival.95th_and_dan_ryan
# Polling for message 445
# {'station_id': 40450, 'train_id': 'RL003', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40450, 'prev_direction': 'a'} com.cta.stations.arrival.95th_and_dan_ryan
# Polling for message 446
# {'station_id': 40450, 'train_id': 'RL002', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41430, 'prev_direction': 'b'} com.cta.stations.arrival.95th_and_dan_ryan
# Polling for message 447
# {'station_id': 40450, 'train_id': 'RL002', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40450, 'prev_direction': 'a'} com.cta.stations.arrival.95th_and_dan_ryan
# Polling for message 448
# {'station_id': 40450, 'train_id': 'RL001', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41430, 'prev_direction': 'b'} com.cta.stations.arrival.95th_and_dan_ryan
# Polling for message 449
# {'station_id': 40650, 'train_id': 'RL007', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41220, 'prev_direction': 'b'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 450
# {'station_id': 40650, 'train_id': 'RL002', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40630, 'prev_direction': 'a'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 451
# {'station_id': 40650, 'train_id': 'RL006', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41220, 'prev_direction': 'b'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 452
# {'station_id': 40650, 'train_id': 'RL001', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40630, 'prev_direction': 'a'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 453
# {'station_id': 40650, 'train_id': 'RL005', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41220, 'prev_direction': 'b'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 454
# {'station_id': 40650, 'train_id': 'RL000', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40630, 'prev_direction': 'a'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 455
# {'station_id': 40650, 'train_id': 'RL004', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41220, 'prev_direction': 'b'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 456
# {'station_id': 40650, 'train_id': 'RL003', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41220, 'prev_direction': 'b'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 457
# {'station_id': 40650, 'train_id': 'RL009', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40630, 'prev_direction': 'a'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 458
# {'station_id': 40650, 'train_id': 'RL002', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41220, 'prev_direction': 'b'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 459
# {'station_id': 40650, 'train_id': 'RL008', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40630, 'prev_direction': 'a'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 460
# {'station_id': 40650, 'train_id': 'RL001', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41220, 'prev_direction': 'b'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 461
# {'station_id': 40650, 'train_id': 'RL007', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40630, 'prev_direction': 'a'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 462
# {'station_id': 40650, 'train_id': 'RL000', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41220, 'prev_direction': 'b'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 463
# {'station_id': 40650, 'train_id': 'RL006', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40630, 'prev_direction': 'a'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 464
# {'station_id': 40650, 'train_id': 'RL005', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40630, 'prev_direction': 'a'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 465
# {'station_id': 41270, 'train_id': 'GL000', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40300, 'prev_direction': 'b'} com.cta.stations.arrival.43rd
# Polling for message 466
# {'station_id': 41270, 'train_id': 'GL002', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41080, 'prev_direction': 'a'} com.cta.stations.arrival.43rd
# Polling for message 467
# {'station_id': 41270, 'train_id': 'GL001', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41080, 'prev_direction': 'a'} com.cta.stations.arrival.43rd
# Polling for message 468
# ...
# Polling for message 4661
# {'station_id': 41690, 'train_id': 'GL006', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41400, 'prev_direction': 'b'} com.cta.stations.arrival.cermak_mccormick_place
# Polling for message 4662
# {'station_id': 40380, 'train_id': 'GL005', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41160, 'prev_direction': 'b'} com.cta.stations.arrival.clark_and_lake
# Polling for message 4663
# {'station_id': 40130, 'train_id': 'GL007', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41080, 'prev_direction': 'b'} com.cta.stations.arrival.51st
# Polling for message 4664
# {'station_id': 40510, 'train_id': 'GL008', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40940, 'prev_direction': 'a'} com.cta.stations.arrival.garfield
# Polling for message 4665
# {'station_id': 41120, 'train_id': 'GL009', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40300, 'prev_direction': 'a'} com.cta.stations.arrival.35th_bronzeville_iit
# Polling for message 4666
# {'station_id': 40170, 'train_id': 'GL000', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41510, 'prev_direction': 'a'} com.cta.stations.arrival.ashland
# Polling for message 4667
# {'station_id': 40480, 'train_id': 'GL001', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40030, 'prev_direction': 'a'} com.cta.stations.arrival.cicero
# Polling for message 4668
# {'station_id': 41350, 'train_id': 'GL002', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40610, 'prev_direction': 'a'} com.cta.stations.arrival.oak_park
# Polling for message 4669
# Message is None
# Polling for message 4670
# Message is None
# Polling for message 4671
# Message is None
# Polling for message 4672
# Message is None
# Polling for message 4673
# Message is None
# Polling for message 4674
# {'station_id': 40230, 'train_id': 'BL001', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40820, 'prev_direction': 'b'} com.cta.stations.arrival.cumberland
# Polling for message 4675
# {'station_id': 40060, 'train_id': 'BL002', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 41240, 'prev_direction': 'b'} com.cta.stations.arrival.belmont
# Polling for message 4676
# {'station_id': 41410, 'train_id': 'BL003', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40320, 'prev_direction': 'b'} com.cta.stations.arrival.chicago
# Polling for message 4677
# {'station_id': 41340, 'train_id': 'BL004', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40070, 'prev_direction': 'b'} com.cta.stations.arrival.lasalle
# Polling for message 4678
# {'station_id': 40810, 'train_id': 'BL007', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40220, 'prev_direction': 'a'} com.cta.stations.arrival.illinois_medical_district
# Polling for message 4679
# {'station_id': 40180, 'train_id': 'BL006', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40390, 'prev_direction': 'a'} com.cta.stations.arrival.oak_park
# Polling for message 4680
# {'station_id': 40250, 'train_id': 'BL005', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40220, 'prev_direction': 'b'} com.cta.stations.arrival.kedzie_homan
# Polling for message 4681
# {'station_id': 41280, 'train_id': 'BL000', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 41330, 'prev_direction': 'a'} com.cta.stations.arrival.jefferson_park
# Polling for message 4682
# {'station_id': 40790, 'train_id': 'BL008', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40070, 'prev_direction': 'a'} com.cta.stations.arrival.monroe
# Polling for message 4683
# {'station_id': 40590, 'train_id': 'BL009', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40320, 'prev_direction': 'a'} com.cta.stations.arrival.damen
# Polling for message 4684
# {'station_id': 40100, 'train_id': 'RL005', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41190, 'prev_direction': 'b'} com.cta.stations.arrival.morse
# Polling for message 4685
# {'station_id': 40760, 'train_id': 'RL004', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40880, 'prev_direction': 'a'} com.cta.stations.arrival.granville
# Polling for message 4686
# {'station_id': 41090, 'train_id': 'RL008', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41660, 'prev_direction': 'b'} com.cta.stations.arrival.monroe
# Polling for message 4687
# {'station_id': 41200, 'train_id': 'RL006', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40340, 'prev_direction': 'b'} com.cta.stations.arrival.argyle
# Polling for message 4688
# {'station_id': 40630, 'train_id': 'RL002', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41450, 'prev_direction': 'a'} com.cta.stations.arrival.clark_and_division
# Polling for message 4689
# {'station_id': 40540, 'train_id': 'RL003', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40080, 'prev_direction': 'a'} com.cta.stations.arrival.wilson
# Polling for message 4690
# {'station_id': 41230, 'train_id': 'RL009', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40190, 'prev_direction': 'b'} com.cta.stations.arrival.47th
# Polling for message 4691
# {'station_id': 40910, 'train_id': 'RL000', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40990, 'prev_direction': 'a'} com.cta.stations.arrival.63rd
# Polling for message 4692
# {'station_id': 41220, 'train_id': 'RL007', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41320, 'prev_direction': 'b'} com.cta.stations.arrival.fullerton
# Polling for message 4693
# {'station_id': 41490, 'train_id': 'RL001', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41400, 'prev_direction': 'a'} com.cta.stations.arrival.harrison
# Polling for message 4694
# {'station_id': 40700, 'train_id': 'GL003', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40280, 'prev_direction': 'b'} com.cta.stations.arrival.laramie
# Polling for message 4695
# {'station_id': 40020, 'train_id': 'GL002', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41350, 'prev_direction': 'a'} com.cta.stations.arrival.harlem_and_lake
# Polling for message 4696
# {'station_id': 40700, 'train_id': 'GL001', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40480, 'prev_direction': 'a'} com.cta.stations.arrival.laramie
# Polling for message 4697
# {'station_id': 41690, 'train_id': 'GL009', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41120, 'prev_direction': 'a'} com.cta.stations.arrival.cermak_mccormick_place
# Polling for message 4698
# {'station_id': 41120, 'train_id': 'GL006', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41690, 'prev_direction': 'b'} com.cta.stations.arrival.35th_bronzeville_iit
# Polling for message 4699
# {'station_id': 41360, 'train_id': 'GL004', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41070, 'prev_direction': 'b'} com.cta.stations.arrival.california
# Polling for message 4700
# {'station_id': 41360, 'train_id': 'GL000', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40170, 'prev_direction': 'a'} com.cta.stations.arrival.california
# Polling for message 4701
# {'station_id': 40130, 'train_id': 'GL008', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40510, 'prev_direction': 'a'} com.cta.stations.arrival.51st
# Polling for message 4702
# {'station_id': 40510, 'train_id': 'GL007', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40130, 'prev_direction': 'b'} com.cta.stations.arrival.garfield
# Polling for message 4703
# {'station_id': 40260, 'train_id': 'GL005', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40380, 'prev_direction': 'b'} com.cta.stations.arrival.state_and_lake
# Polling for message 4704
# Message is None
# Polling for message 4705
# Message is None
# Polling for message 4706
# Message is None
# Polling for message 4707
# Message is None
# Polling for message 4708
# Message is None
# Polling for message 4709
# {'station_id': 40750, 'train_id': 'BL001', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40230, 'prev_direction': 'b'} com.cta.stations.arrival.harlem
# Polling for message 4710
# {'station_id': 41020, 'train_id': 'BL002', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40060, 'prev_direction': 'b'} com.cta.stations.arrival.logan_square
# Polling for message 4711
# {'station_id': 40490, 'train_id': 'BL003', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 41410, 'prev_direction': 'b'} com.cta.stations.arrival.grand
# Polling for message 4712
# {'station_id': 40430, 'train_id': 'BL004', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 41340, 'prev_direction': 'b'} com.cta.stations.arrival.clinton
# Polling for message 4713
# {'station_id': 40010, 'train_id': 'BL006', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40180, 'prev_direction': 'a'} com.cta.stations.arrival.austin
# Polling for message 4714
# {'station_id': 40470, 'train_id': 'BL007', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40810, 'prev_direction': 'a'} com.cta.stations.arrival.racine
# Polling for message 4715
# {'station_id': 40920, 'train_id': 'BL005', 'direction': 'b', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40250, 'prev_direction': 'b'} com.cta.stations.arrival.pulaski
# Polling for message 4716
# {'station_id': 40370, 'train_id': 'BL008', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40790, 'prev_direction': 'a'} com.cta.stations.arrival.washington
# Polling for message 4717
# {'station_id': 40750, 'train_id': 'BL000', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 41280, 'prev_direction': 'a'} com.cta.stations.arrival.harlem
# Polling for message 4718
# {'station_id': 40670, 'train_id': 'BL009', 'direction': 'a', 'line': 'blue', 'train_status': 'in_service', 'prev_station_id': 40590, 'prev_direction': 'a'} com.cta.stations.arrival.western_and_ohare_branch
# Polling for message 4719
# {'station_id': 41300, 'train_id': 'RL005', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40100, 'prev_direction': 'b'} com.cta.stations.arrival.loyola
# Polling for message 4720
# {'station_id': 40560, 'train_id': 'RL008', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41090, 'prev_direction': 'b'} com.cta.stations.arrival.jackson
# Polling for message 4721
# {'station_id': 40770, 'train_id': 'RL006', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41200, 'prev_direction': 'b'} com.cta.stations.arrival.lawrence
# Polling for message 4722
# {'station_id': 40650, 'train_id': 'RL007', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41220, 'prev_direction': 'b'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 4723
# {'station_id': 40560, 'train_id': 'RL001', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41490, 'prev_direction': 'a'} com.cta.stations.arrival.jackson
# Polling for message 4724
# {'station_id': 41170, 'train_id': 'RL009', 'direction': 'b', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 41230, 'prev_direction': 'b'} com.cta.stations.arrival.garfield
# Polling for message 4725
# {'station_id': 41170, 'train_id': 'RL000', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40910, 'prev_direction': 'a'} com.cta.stations.arrival.garfield
# Polling for message 4726
# {'station_id': 40770, 'train_id': 'RL003', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40540, 'prev_direction': 'a'} com.cta.stations.arrival.lawrence
# Polling for message 4727
# {'station_id': 40650, 'train_id': 'RL002', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40630, 'prev_direction': 'a'} com.cta.stations.arrival.north_and_clybourn
# Polling for message 4728
# {'station_id': 41300, 'train_id': 'RL004', 'direction': 'a', 'line': 'red', 'train_status': 'in_service', 'prev_station_id': 40760, 'prev_direction': 'a'} com.cta.stations.arrival.loyola
# Polling for message 4729
# {'station_id': 41350, 'train_id': 'GL002', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40020, 'prev_direction': 'b'} com.cta.stations.arrival.oak_park
# Polling for message 4730
# {'station_id': 40480, 'train_id': 'GL003', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40700, 'prev_direction': 'b'} com.cta.stations.arrival.cicero
# Polling for message 4731
# {'station_id': 40170, 'train_id': 'GL004', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41360, 'prev_direction': 'b'} com.cta.stations.arrival.ashland
# Polling for message 4732
# {'station_id': 40300, 'train_id': 'GL006', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41120, 'prev_direction': 'b'} com.cta.stations.arrival.indiana
# Polling for message 4733
# {'station_id': 41070, 'train_id': 'GL000', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41360, 'prev_direction': 'a'} com.cta.stations.arrival.kedzie
# Polling for message 4734
# {'station_id': 40940, 'train_id': 'GL007', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40510, 'prev_direction': 'b'} com.cta.stations.arrival.halsted
# Polling for message 4735
# {'station_id': 41700, 'train_id': 'GL005', 'direction': 'b', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40260, 'prev_direction': 'b'} com.cta.stations.arrival.washington_and_wabash
# Polling for message 4736
# {'station_id': 41400, 'train_id': 'GL009', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 41690, 'prev_direction': 'a'} com.cta.stations.arrival.roosevelt
# Polling for message 4737
# {'station_id': 41080, 'train_id': 'GL008', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40130, 'prev_direction': 'a'} com.cta.stations.arrival.47th
# Polling for message 4738
# {'station_id': 40280, 'train_id': 'GL001', 'direction': 'a', 'line': 'green', 'train_status': 'in_service', 'prev_station_id': 40700, 'prev_direction': 'a'} com.cta.stations.arrival.central
# Polling for message 4739
# Message is None
# Polling for message 4740
# Message is None
# Polling for message 4741
# Message is None
# Polling for message 4742
# Message is None
# Polling for message 4743
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-a1197b1c82e7> in <module>
#      16         i+=1
#      17         print('Polling for message',i)
# ---> 18         msg = c.poll(1)
#      19
#      20     except SerializerError as e:
#
# /opt/conda/lib/python3.7/site-packages/confluent_kafka/avro/__init__.py in poll(self, timeout)
#     137         if timeout is None:
#     138             timeout = -1
# --> 139         message = super(AvroConsumer, self).poll(timeout)
#     140         if message is None:
#     141             return None
#
# KeyboardInterrupt:
